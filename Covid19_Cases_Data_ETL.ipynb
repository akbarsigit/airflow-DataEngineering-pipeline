# %% [markdown]
# # **Covid Data Processing**
# #### Kelompok 9 Rekayasa Data
# ---

# %% [markdown]
# # **Data Extracting**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.DataFrame()

for i in range (22, 30):
  if i < 10:
    day = '0' + str(i)
  else:
    day = str (i)

  url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/11-' + day + '-2022.csv'
  df_to_append = pd.read_csv(url)

  df = df.append(df_to_append)

print('Append success')
# Out:
# Append success

# %%
df = df.sort_values(['Country_Region', 'Province_State','Last_Update'])
df
# Out:
#       FIPS Admin2 Province_State Country_Region          Last_Update  \
# 0      NaN    NaN            NaN    Afghanistan  2022-11-23 04:21:06
# 0      NaN    NaN            NaN    Afghanistan  2022-11-24 04:21:09
# 0      NaN    NaN            NaN    Afghanistan  2022-11-25 04:21:06
# 0      NaN    NaN            NaN    Afghanistan  2022-11-26 04:21:11
# 0      NaN    NaN            NaN    Afghanistan  2022-11-27 04:21:05
# ...    ...    ...            ...            ...                  ...
# 4015   NaN    NaN            NaN       Zimbabwe  2022-11-26 04:21:11
# 4015   NaN    NaN            NaN       Zimbabwe  2022-11-27 04:21:05
# 4015   NaN    NaN            NaN       Zimbabwe  2022-11-28 04:21:02
# 4015   NaN    NaN            NaN       Zimbabwe  2022-11-29 04:21:05
# 4015   NaN    NaN            NaN       Zimbabwe  2022-11-30 04:21:07
#
#             Lat      Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0     33.939110  67.709953     205324    7833        NaN     NaN  Afghanistan
# 0     33.939110  67.709953     205391    7833        NaN     NaN  Afghanistan
# 0     33.939110  67.709953     205506    7833        NaN     NaN  Afghanistan
# 0     33.939110  67.709953     205541    7833        NaN     NaN  Afghanistan
# 0     33.939110  67.709953     205612    7833        NaN     NaN  Afghanistan
# ...         ...        ...        ...     ...        ...     ...          ...
# 4015 -19.015438  29.154857     257893    5606        NaN     NaN     Zimbabwe
# 4015 -19.015438  29.154857     257893    5606        NaN     NaN     Zimbabwe
# 4015 -19.015438  29.154857     257893    5606        NaN     NaN     Zimbabwe
# 4015 -19.015438  29.154857     257893    5606        NaN     NaN     Zimbabwe
# 4015 -19.015438  29.154857     257893    5606        NaN     NaN     Zimbabwe
#
#       Incident_Rate  Case_Fatality_Ratio
# 0        527.440920             3.814946
# 0        527.613031             3.813702
# 0        527.908446             3.811568
# 0        527.998355             3.810919
# 0        528.180741             3.809603
# ...             ...                  ...
# 4015    1735.142748             2.173770
# 4015    1735.142748             2.173770
# 4015    1735.142748             2.173770
# 4015    1735.142748             2.173770
# 4015    1735.142748             2.173770
#
# [32128 rows x 14 columns]

# %%
#Karena kami hanya membutuhkan lima atribut yaitu Last_Update, Province_State, Country_Region, Confirmed, dan Deaths
#maka kami membuat dataframe baru yang hanya mengandung 5 atribut tersebut
df["Last_Update"] = pd.to_datetime(df["Last_Update"]).dt.strftime('%Y-%m-%d')
df2 = df[['Last_Update', 'Province_State','Country_Region', 'Confirmed', 'Deaths']].copy()
df2
# Out:
#      Last_Update Province_State Country_Region  Confirmed  Deaths
# 0     2022-11-23            NaN    Afghanistan     205324    7833
# 0     2022-11-24            NaN    Afghanistan     205391    7833
# 0     2022-11-25            NaN    Afghanistan     205506    7833
# 0     2022-11-26            NaN    Afghanistan     205541    7833
# 0     2022-11-27            NaN    Afghanistan     205612    7833
# ...          ...            ...            ...        ...     ...
# 4015  2022-11-26            NaN       Zimbabwe     257893    5606
# 4015  2022-11-27            NaN       Zimbabwe     257893    5606
# 4015  2022-11-28            NaN       Zimbabwe     257893    5606
# 4015  2022-11-29            NaN       Zimbabwe     257893    5606
# 4015  2022-11-30            NaN       Zimbabwe     257893    5606
#
# [32128 rows x 5 columns]

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# ###**Handle missing values**

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32128 entries, 0 to 4015
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Last_Update     32128 non-null  object
#  1   Province_State  30696 non-null  object
#  2   Country_Region  32128 non-null  object
#  3   Confirmed       32128 non-null  int64
#  4   Deaths          32128 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df2.isnull().sum()
# Out:
# Last_Update          0
# Province_State    1432
# Country_Region       0
# Confirmed            0
# Deaths               0
# dtype: int64

# %%
#Terlihat bahwa attribut yang memiliki missing values adalah atribut Province_State
#Sehingga, untuk mengatasi hal ini, akan dilakukan pengisian missing values dengan mean dari atribut yang bersangkutan

df2['Province_State'] = df2['Province_State'].fillna('Unknown')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32128 entries, 0 to 4015
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Last_Update     32128 non-null  object
#  1   Province_State  32128 non-null  object
#  2   Country_Region  32128 non-null  object
#  3   Confirmed       32128 non-null  int64
#  4   Deaths          32128 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# # **Data Transform**

# %%
#Kolom baru untuk mendapatkan kasus terkonfirmasi dan kasus meninggal perhari
for data in range(0,len(df2)):
  df2['Confirmed_perday'] = df2['Confirmed'] - df2['Confirmed'].shift()
  df2['Deaths_perday'] = df2['Deaths'] - df2['Deaths'].shift()

# %%
df2
# Out:
#      Last_Update Province_State Country_Region  Confirmed  Deaths  \
# 0     2022-11-23        Unknown    Afghanistan     205324    7833
# 0     2022-11-24        Unknown    Afghanistan     205391    7833
# 0     2022-11-25        Unknown    Afghanistan     205506    7833
# 0     2022-11-26        Unknown    Afghanistan     205541    7833
# 0     2022-11-27        Unknown    Afghanistan     205612    7833
# ...          ...            ...            ...        ...     ...
# 4015  2022-11-26        Unknown       Zimbabwe     257893    5606
# 4015  2022-11-27        Unknown       Zimbabwe     257893    5606
# 4015  2022-11-28        Unknown       Zimbabwe     257893    5606
# 4015  2022-11-29        Unknown       Zimbabwe     257893    5606
# 4015  2022-11-30        Unknown       Zimbabwe     257893    5606
#
#       Confirmed_perday  Deaths_perday
# 0                  NaN            NaN
# 0                 67.0            0.0
# 0                115.0            0.0
# 0                 35.0            0.0
# 0                 71.0            0.0
# ...                ...            ...
# 4015               0.0            0.0
# 4015               0.0            0.0
# 4015               0.0            0.0
# 4015               0.0            0.0
# 4015               0.0            0.0
#
# [32128 rows x 7 columns]

# %% [markdown]
# # **Download Data**

# %%
from google.colab import files

df2.to_csv('covid-19_cases_global.csv')
files.download('covid-19_cases_global.csv')
